# %% [markdown]
# # AXOLOTL

# %% [markdown]
# #### ResNet50 - Arquitetura com blocos residuais, melhor precisão em conjuntos de dados desafiadores.

# %%
#IMAGEM 1

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

modelo = ResNet50(weights='imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/axolotl.jpg', target_size=(224, 224))

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Exibir a imagem
plt.imshow(img)
plt.axis('off')
plt.show()

# Obter as previsões
previsoes = decode_predictions(preds, top=3)[0]

print('Previsões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 1s 760ms/step
# Previsões:
#
# axolotl: 0.99999332427978515625
#
# banded_gecko: 0.00000633941408523242
#
# common_newt: 0.00000010523950066954

# %%
#IMAGEM 2

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

modelo = ResNet50(weights='imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/axolotl3.jpg', target_size=(224, 224))

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Exibir a imagem
plt.imshow(img)
plt.axis('off')
plt.show()

# Obter as previsões
previsoes = decode_predictions(preds, top=3)[0]

print('Previsões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 1s 765ms/step
# Previsões:
#
# axolotl: 0.99999988079071044922
#
# banded_gecko: 0.00000010791234217322
#
# spotted_salamander: 0.00000000512787989848

# %% [markdown]
# #### VGG16 - Arquitetura relativamente simples, precisa de mais recursos computacionais.

# %%
#IMAGEM 1

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

modelo = VGG16(weights = 'imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/axolotl.jpg', target_size = (224, 224))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Obter as previsões
previsoes = decode_predictions(preds, top=3)[0]

print('\nPrevisões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 0s 259ms/step
#
# Previsões:
#
# axolotl: 1.00000000000000000000
#
# common_newt: 0.00000000016358794874
#
# banded_gecko: 0.00000000003928395109

# %%
#IMAGEM 2

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

modelo = VGG16(weights = 'imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/axolotl3.jpg', target_size = (224, 224))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Obter as previsões
previsoes = decode_predictions(preds, top=3)[0]

print('\nPrevisões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 0s 262ms/step
#
# Previsões:
#
# axolotl: 1.00000000000000000000
#
# common_newt: 0.00000000004758728481
#
# banded_gecko: 0.00000000001493555279

# %% [markdown]
# #### InceptionV3 - Utiliza módulos Inception para extrair informações em diferentes escalas espaciais.

# %%
#IMAGEM 1

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

modelo = InceptionV3(weights='imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/axolotl.jpg', target_size = (299, 299)) #TIVE QUE MUDAR DE 224 PRA 299

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Obter as previsões
previsoes = decode_predictions(preds, top=5)[0]

print('\nPrevisões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 1s 983ms/step
#
# Previsões:
#
# axolotl: 0.89313471317291259766
#
# dumbbell: 0.00383928790688514709
#
# barbell: 0.00151096272747963667
#
# common_newt: 0.00113182235509157181
#
# sulphur-crested_cockatoo: 0.00105345179326832294

# %%
#IMAGEM 2

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

modelo = InceptionV3(weights='imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/axolotl3.jpg', target_size = (299, 299)) #TIVE QUE MUDAR DE 224 PRA 299

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Obter as previsões
previsoes = decode_predictions(preds, top=5)[0]

print('\nPrevisões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 1s 969ms/step
#
# Previsões:
#
# axolotl: 0.92548978328704833984
#
# dumbbell: 0.00208767387084662914
#
# common_newt: 0.00098466349299997091
#
# sulphur-crested_cockatoo: 0.00079981761518865824
#
# viaduct: 0.00057993730297312140

# %% [markdown]
# #### MobileNetV2 - Projetado para dispositivos móveis e aplicações com recursos limitados, é eficiente em termos de tamanho do modelo e uso de recursos.

# %%
#IMAGEM 1

from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

modelo = MobileNetV2(weights='imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/axolotl.jpg', target_size = (224, 224)) 

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Obter as previsões
previsoes = decode_predictions(preds, top=3)[0]

print('\nPrevisões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 1s 612ms/step
#
# Previsões:
#
# axolotl: 0.93173396587371826172
#
# banded_gecko: 0.00418992666527628899
#
# sea_slug: 0.00259156920947134495

# %%
#IMAGEM 2

from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

modelo = MobileNetV2(weights='imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/axolotl.jpg', target_size = (224, 224)) 

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Obter as previsões
previsoes = decode_predictions(preds, top=3)[0]

print('\nPrevisões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 1s 597ms/step
#
# Previsões:
#
# axolotl: 0.93173396587371826172
#
# banded_gecko: 0.00418992666527628899
#
# sea_slug: 0.00259156920947134495

# %% [markdown]
# # CROCODILE

# %%
path = "d:/teti/aulas/TETI_ATV4/imagens/"

# Definir imagens
imagens = [
    'crocodile.jpg',
    'crocodile2.jpg'
]

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Exibir imagens
for imagem in imagens:
    img_path = path + imagem  # Concatenar o caminho com o nome da imagem
    img = Image.open(img_path)
    
    # Exibir imagem
    plt.imshow(img)
    plt.axis('off')  # Remover os eixos
    plt.show()

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# Definir modelos
modelos = [
    (ResNet50(weights='imagenet'), 'ResNet50'), #defini com o nome para exibir depois
    (VGG16(weights='imagenet'), 'VGG16'),
    (MobileNet(weights='imagenet'), 'MobileNet')
]

# Loop para testar cada modelo com cada imagem
for modelo, nome_modelo in modelos:
    for imagem in imagens:
        # Carregar imagem
        img_path = path + imagem  # Concatenar o caminho com o nome da imagem
        img = image.load_img(img_path, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        # Obter as previsões
        preds = modelo.predict(x)
        previsoes = decode_predictions(preds, top=3)[0]

        # Exibir resultados
        print(f'Previsões para {imagem} usando {nome_modelo}:')
        for _, classe, probabilidade in previsoes:
            print(f'{classe}: {probabilidade:.2%}')
        print()

        
#o mobilenetv2 fez previsoes ruins
# Out:
# 1/1 [==============================] - 1s 812ms/step
# Previsões para crocodile.jpg usando ResNet50:
# African_crocodile: 96.10%
# American_alligator: 2.38%
# Komodo_dragon: 0.71%
#
# 1/1 [==============================] - 0s 90ms/step
# Previsões para crocodile2.jpg usando ResNet50:
# African_crocodile: 78.92%
# American_alligator: 20.92%
# Komodo_dragon: 0.05%
#
# 1/1 [==============================] - 0s 247ms/step
# Previsões para crocodile.jpg usando VGG16:
# African_crocodile: 99.20%
# American_alligator: 0.80%
# Komodo_dragon: 0.00%
#
# 1/1 [==============================] - 0s 169ms/step
# Previsões para crocodile2.jpg usando VGG16:
# African_crocodile: 68.56%
# American_alligator: 31.26%
# common_iguana: 0.05%
#
# 1/1 [==============================] - 0s 340ms/step
# Previsões para crocodile.jpg usando MobileNet:
# sock: 18.60%
# snowmobile: 8.70%
# mitten: 8.21%
#
# 1/1 [==============================] - 0s 42ms/step
# Previsões para crocodile2.jpg usando MobileNet:
# prayer_rug: 38.42%
# mosquito_net: 12.85%
# water_snake: 8.35%

# %% [markdown]
# #### INCEPTION

# %%
#IMAGEM 1

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

modelo = InceptionV3(weights='imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/crocodile.jpg', target_size = (299, 299)) #TIVE QUE MUDAR DE 224 PRA 299

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Obter as previsões
previsoes = decode_predictions(preds, top=5)[0]

print('\nPrevisões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# 1/1 [==============================] - 1s 983ms/step
#
# Previsões:
#
# African_crocodile: 0.92122393846511840820
#
# American_alligator: 0.00821315217763185501
#
# refrigerator: 0.00086506357183679938
#
# barbershop: 0.00051758834160864353
#
# comic_book: 0.00049947027582675219

# %%
#IMAGEM 2

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

modelo = InceptionV3(weights='imagenet')

img = image.load_img('d:/teti/aulas/TETI_ATV4/imagens/crocodile2.jpg', target_size = (299, 299)) #TIVE QUE MUDAR DE 224 PRA 299

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

preds = modelo.predict(x)

# Obter as previsões
previsoes = decode_predictions(preds, top=5)[0]

print('\nPrevisões:\n')
for _, classe, probabilidade in previsoes:
    print(f'{classe}: {probabilidade:.20f}\n')
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002828A4549A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
#
# Previsões:
#
# African_crocodile: 0.95282524824142456055
#
# American_alligator: 0.00866093952208757401
#
# diamondback: 0.00070254411548376083
#
# horned_viper: 0.00065347307827323675
#
# starfish: 0.00034572766162455082
